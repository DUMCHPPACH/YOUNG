# %%
# https://wikidocs.net/57165

# %% [markdown]
# ---
# # 07. 커스텀 데이터셋(Custom Dataset)

# %%
# 커스텀 데이터셋을 만들 때 필요한 뼈대는 아래와 같다.
import torch

class CustomDataset(torch.utils.data.Dataset):
    def __init__(self):
        # 데이터셋의 전처리를 해주는 부분

    def __len__(self):
        # 데이터셋의 길이. 즉, 총 샘플의 수를 적어주는 부분
        # len(dataset)을 했을 때 크기를 리턴한다.

    def __getitem__(self, idx):
        # 데이터셋에서 특정 1개의 샘플을 가져오는 함수
        # dataset[i]를 할 때 i번째 샘플을 가져오도록 한다.

# %% [markdown]
# ---
# ---

# %%
import torch
import torch.nn.functional as F

# %%
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# %%
# dataset 상속
class CustomDataset(Dataset):
    def __init__(self):
        self.x_data = [[73, 80, 75],
                    [93, 88, 93],
                    [89, 91, 90],
                    [96, 98, 100],
                    [73, 66, 70]]
        self.y_data = [[152], [185], [180], [196], [142]]
    
    # len(dataset)
    def __len__(self):
        return len(self.x_data)
    
    # dataset[i]
    def __getitem__(self, idx):
        x = torch.FloatTensor(self.x_data[idx])
        y = torch.FloatTensor(self.y_data[idx])
        return x, y

# %%
dataset = CustomDataset()
dataloader = DataLoader(dataset, batch_size = 2, shuffle = True)

# %%
model = torch.nn.Linear(3, 1)
optimizer = torch.optim.SGD(model.parameters(), lr = 1e-5)

# %%
# 학습 진행

nb_epochs = 100
for epoch in range(nb_epochs + 1 ):
    for batch_idx, samples in enumerate(dataloader):
        # print(batch_idx)
        # print(samples)
        x_train, y_train = samples

        # H(x) 계산
        prediction = model(x_train)

        # cost 계산
        cost = F.mse_loss(prediction, y_train)

        #cost로 H(x) 계산
        optimizer.zero_grad()
        cost.backward()
        optimizer.step()

        print('Epoch {:4d}/{}  Batch {}/{}  Cost {:.4f}'.format(
            epoch, nb_epochs, batch_idx+1, len(dataloader), cost.item()
        ))
# Out:
# Epoch    0/100  Batch 1/3  Cost 0.0887
# Epoch    0/100  Batch 2/3  Cost 0.5510
# Epoch    0/100  Batch 3/3  Cost 0.0149
# Epoch    1/100  Batch 1/3  Cost 0.4490
# Epoch    1/100  Batch 2/3  Cost 0.0049
# Epoch    1/100  Batch 3/3  Cost 0.3464
# Epoch    2/100  Batch 1/3  Cost 0.0830
# Epoch    2/100  Batch 2/3  Cost 0.5429
# Epoch    2/100  Batch 3/3  Cost 0.0133
# Epoch    3/100  Batch 1/3  Cost 0.1364
# Epoch    3/100  Batch 2/3  Cost 0.4325
# Epoch    3/100  Batch 3/3  Cost 0.3172
# Epoch    4/100  Batch 1/3  Cost 0.0505
# Epoch    4/100  Batch 2/3  Cost 0.5557
# Epoch    4/100  Batch 3/3  Cost 0.0448
# Epoch    5/100  Batch 1/3  Cost 0.4758
# Epoch    5/100  Batch 2/3  Cost 0.0028
# Epoch    5/100  Batch 3/3  Cost 0.2802
# Epoch    6/100  Batch 1/3  Cost 0.0802
# Epoch    6/100  Batch 2/3  Cost 0.1633
# Epoch    6/100  Batch 3/3  Cost 1.1353
# Epoch    7/100  Batch 1/3  Cost 0.4191
# Epoch    7/100  Batch 2/3  Cost 0.5188
# Epoch    7/100  Batch 3/3  Cost 0.0002
# Epoch    8/100  Batch 1/3  Cost 0.4699
# Epoch    8/100  Batch 2/3  Cost 0.0005
# Epoch    8/100  Batch 3/3  Cost 0.3111
# Epoch    9/100  Batch 1/3  Cost 0.5110
# Epoch    9/100  Batch 2/3  Cost 0.2905
# Epoch    9/100  Batch 3/3  Cost 0.1251
# Epoch   10/100  Batch 1/3  Cost 0.0933
# Epoch   10/100  Batch 2/3  Cost 0.5074
# Epoch   10/100  Batch 3/3  Cost 0.0064
# Epoch   11/100  Batch 1/3  Cost 0.1494
# Epoch   11/100  Batch 2/3  Cost 0.4676
# Epoch   11/100  Batch 3/3  Cost 0.0038
# Epoch   12/100  Batch 1/3  Cost 0.1131
# Epoch   12/100  Batch 2/3  Cost 0.1182
# Epoch   12/100  Batch 3/3  Cost 0.8945
# Epoch   13/100  Batch 1/3  Cost 0.4454
# Epoch   13/100  Batch 2/3  Cost 0.2541
# Epoch   13/100  Batch 3/3  Cost 0.0174
# Epoch   14/100  Batch 1/3  Cost 0.3039
# Epoch   14/100  Batch 2/3  Cost 0.5687
# Epoch   14/100  Batch 3/3  Cost 0.0000
# Epoch   15/100  Batch 1/3  Cost 0.1422
# Epoch   15/100  Batch 2/3  Cost 0.1179
# Epoch   15/100  Batch 3/3  Cost 0.8997
# Epoch   16/100  Batch 1/3  Cost 0.1987
# Epoch   16/100  Batch 2/3  Cost 0.7093
# Epoch   16/100  Batch 3/3  Cost 0.0170
# Epoch   17/100  Batch 1/3  Cost 0.0181
# Epoch   17/100  Batch 2/3  Cost 0.2599
# Epoch   17/100  Batch 3/3  Cost 1.0472
# Epoch   18/100  Batch 1/3  Cost 0.0047
# Epoch   18/100  Batch 2/3  Cost 0.4715
# Epoch   18/100  Batch 3/3  Cost 0.3483
# Epoch   19/100  Batch 1/3  Cost 0.0800
# Epoch   19/100  Batch 2/3  Cost 0.0825
# Epoch   19/100  Batch 3/3  Cost 1.0178
# Epoch   20/100  Batch 1/3  Cost 0.4338
# Epoch   20/100  Batch 2/3  Cost 0.2325
# Epoch   20/100  Batch 3/3  Cost 0.0061
# Epoch   21/100  Batch 1/3  Cost 0.1126
# Epoch   21/100  Batch 2/3  Cost 0.4961
# Epoch   21/100  Batch 3/3  Cost 0.0048
# Epoch   22/100  Batch 1/3  Cost 0.2588
# Epoch   22/100  Batch 2/3  Cost 0.5536
# Epoch   22/100  Batch 3/3  Cost 0.0120
# Epoch   23/100  Batch 1/3  Cost 0.1814
# Epoch   23/100  Batch 2/3  Cost 0.4536
# Epoch   23/100  Batch 3/3  Cost 0.0025
# Epoch   24/100  Batch 1/3  Cost 0.1232
# Epoch   24/100  Batch 2/3  Cost 0.3947
# Epoch   24/100  Batch 3/3  Cost 0.4359
# Epoch   25/100  Batch 1/3  Cost 0.5379
# Epoch   25/100  Batch 2/3  Cost 0.0267
# Epoch   25/100  Batch 3/3  Cost 0.2026
# Epoch   26/100  Batch 1/3  Cost 0.0487
# Epoch   26/100  Batch 2/3  Cost 0.5657
# Epoch   26/100  Batch 3/3  Cost 0.0529
# Epoch   27/100  Batch 1/3  Cost 0.4349
# Epoch   27/100  Batch 2/3  Cost 0.1711
# Epoch   27/100  Batch 3/3  Cost 0.0445
# Epoch   28/100  Batch 1/3  Cost 0.1129
# Epoch   28/100  Batch 2/3  Cost 0.1191
# Epoch   28/100  Batch 3/3  Cost 0.8885
# Epoch   29/100  Batch 1/3  Cost 0.2616
# Epoch   29/100  Batch 2/3  Cost 0.1608
# Epoch   29/100  Batch 3/3  Cost 0.7899
# Epoch   30/100  Batch 1/3  Cost 0.1810
# Epoch   30/100  Batch 2/3  Cost 0.3800
# Epoch   30/100  Batch 3/3  Cost 0.3937
# Epoch   31/100  Batch 1/3  Cost 0.0772
# Epoch   31/100  Batch 2/3  Cost 0.7298
# Epoch   31/100  Batch 3/3  Cost 0.0040
# Epoch   32/100  Batch 1/3  Cost 0.1189
# Epoch   32/100  Batch 2/3  Cost 0.4925
# Epoch   32/100  Batch 3/3  Cost 0.0046
# Epoch   33/100  Batch 1/3  Cost 0.0069
# Epoch   33/100  Batch 2/3  Cost 0.4278
# Epoch   33/100  Batch 3/3  Cost 0.3702
# Epoch   34/100  Batch 1/3  Cost 0.1094
# Epoch   34/100  Batch 2/3  Cost 0.0503
# Epoch   34/100  Batch 3/3  Cost 1.0158
# Epoch   35/100  Batch 1/3  Cost 0.4318
# Epoch   35/100  Batch 2/3  Cost 0.2318
# Epoch   35/100  Batch 3/3  Cost 0.0064
# Epoch   36/100  Batch 1/3  Cost 0.3350
# Epoch   36/100  Batch 2/3  Cost 0.2310
# Epoch   36/100  Batch 3/3  Cost 0.2903
# Epoch   37/100  Batch 1/3  Cost 0.5470
# Epoch   37/100  Batch 2/3  Cost 0.0323
# Epoch   37/100  Batch 3/3  Cost 0.2712
# Epoch   38/100  Batch 1/3  Cost 0.5533
# Epoch   38/100  Batch 2/3  Cost 0.1204
# Epoch   38/100  Batch 3/3  Cost 0.0309
# Epoch   39/100  Batch 1/3  Cost 0.3977
# Epoch   39/100  Batch 2/3  Cost 0.2157
# Epoch   39/100  Batch 3/3  Cost 0.1716
# Epoch   40/100  Batch 1/3  Cost 0.0491
# Epoch   40/100  Batch 2/3  Cost 0.6015
# Epoch   40/100  Batch 3/3  Cost 0.3427
# Epoch   41/100  Batch 1/3  Cost 0.0745
# Epoch   41/100  Batch 2/3  Cost 0.6103
# Epoch   41/100  Batch 3/3  Cost 0.2560
# Epoch   42/100  Batch 1/3  Cost 0.5229
# Epoch   42/100  Batch 2/3  Cost 0.0264
# Epoch   42/100  Batch 3/3  Cost 0.2840
# Epoch   43/100  Batch 1/3  Cost 0.5714
# Epoch   43/100  Batch 2/3  Cost 0.0656
# Epoch   43/100  Batch 3/3  Cost 0.0905
# Epoch   44/100  Batch 1/3  Cost 0.1407
# Epoch   44/100  Batch 2/3  Cost 0.4676
# Epoch   44/100  Batch 3/3  Cost 0.0052
# Epoch   45/100  Batch 1/3  Cost 0.1561
# Epoch   45/100  Batch 2/3  Cost 0.4060
# Epoch   45/100  Batch 3/3  Cost 0.3369
# Epoch   46/100  Batch 1/3  Cost 0.0889
# Epoch   46/100  Batch 2/3  Cost 0.6580
# Epoch   46/100  Batch 3/3  Cost 0.0319
# Epoch   47/100  Batch 1/3  Cost 0.3109
# Epoch   47/100  Batch 2/3  Cost 0.5220
# Epoch   47/100  Batch 3/3  Cost 0.0311
# Epoch   48/100  Batch 1/3  Cost 0.1102
# Epoch   48/100  Batch 2/3  Cost 0.0804
# Epoch   48/100  Batch 3/3  Cost 0.9107
# Epoch   49/100  Batch 1/3  Cost 0.0116
# Epoch   49/100  Batch 2/3  Cost 0.4295
# Epoch   49/100  Batch 3/3  Cost 0.4582
# Epoch   50/100  Batch 1/3  Cost 0.4918
# Epoch   50/100  Batch 2/3  Cost 0.1743
# Epoch   50/100  Batch 3/3  Cost 0.1406
# Epoch   51/100  Batch 1/3  Cost 0.1148
# Epoch   51/100  Batch 2/3  Cost 0.5424
# Epoch   51/100  Batch 3/3  Cost 0.2240
# Epoch   52/100  Batch 1/3  Cost 0.5547
# Epoch   52/100  Batch 2/3  Cost 0.0696
# Epoch   52/100  Batch 3/3  Cost 0.0856
# Epoch   53/100  Batch 1/3  Cost 0.4762
# Epoch   53/100  Batch 2/3  Cost 0.0059
# Epoch   53/100  Batch 3/3  Cost 0.2675
# Epoch   54/100  Batch 1/3  Cost 0.5210
# Epoch   54/100  Batch 2/3  Cost 0.2793
# Epoch   54/100  Batch 3/3  Cost 0.1329
# Epoch   55/100  Batch 1/3  Cost 0.4838
# Epoch   55/100  Batch 2/3  Cost 0.1071
# Epoch   55/100  Batch 3/3  Cost 0.0544
# Epoch   56/100  Batch 1/3  Cost 0.3304
# Epoch   56/100  Batch 2/3  Cost 0.2763
# Epoch   56/100  Batch 3/3  Cost 0.2121
# Epoch   57/100  Batch 1/3  Cost 0.1114
# Epoch   57/100  Batch 2/3  Cost 0.0501
# Epoch   57/100  Batch 3/3  Cost 1.0175
# Epoch   58/100  Batch 1/3  Cost 0.2579
# Epoch   58/100  Batch 2/3  Cost 0.4340
# Epoch   58/100  Batch 3/3  Cost 0.0009
# Epoch   59/100  Batch 1/3  Cost 0.2936
# Epoch   59/100  Batch 2/3  Cost 0.2412
# Epoch   59/100  Batch 3/3  Cost 0.2969
# Epoch   60/100  Batch 1/3  Cost 0.0730
# Epoch   60/100  Batch 2/3  Cost 0.5558
# Epoch   60/100  Batch 3/3  Cost 0.0524
# Epoch   61/100  Batch 1/3  Cost 0.1105
# Epoch   61/100  Batch 2/3  Cost 0.1201
# Epoch   61/100  Batch 3/3  Cost 0.8805
# Epoch   62/100  Batch 1/3  Cost 0.3024
# Epoch   62/100  Batch 2/3  Cost 0.3163
# Epoch   62/100  Batch 3/3  Cost 0.4401
# Epoch   63/100  Batch 1/3  Cost 0.1101
# Epoch   63/100  Batch 2/3  Cost 0.6382
# Epoch   63/100  Batch 3/3  Cost 0.0290
# Epoch   64/100  Batch 1/3  Cost 0.1250
# Epoch   64/100  Batch 2/3  Cost 0.4906
# Epoch   64/100  Batch 3/3  Cost 0.0197
# Epoch   65/100  Batch 1/3  Cost 0.1351
# Epoch   65/100  Batch 2/3  Cost 0.1176
# Epoch   65/100  Batch 3/3  Cost 0.8891
# Epoch   66/100  Batch 1/3  Cost 0.2551
# Epoch   66/100  Batch 2/3  Cost 0.1608
# Epoch   66/100  Batch 3/3  Cost 0.7815
# Epoch   67/100  Batch 1/3  Cost 0.1776
# Epoch   67/100  Batch 2/3  Cost 0.3932
# Epoch   67/100  Batch 3/3  Cost 0.3787
# Epoch   68/100  Batch 1/3  Cost 0.5445
# Epoch   68/100  Batch 2/3  Cost 0.0720
# Epoch   68/100  Batch 3/3  Cost 0.0841
# Epoch   69/100  Batch 1/3  Cost 0.4737
# Epoch   69/100  Batch 2/3  Cost 0.0061
# Epoch   69/100  Batch 3/3  Cost 0.2693
# Epoch   70/100  Batch 1/3  Cost 0.5179
# Epoch   70/100  Batch 2/3  Cost 0.1240
# Epoch   70/100  Batch 3/3  Cost 0.2128
# Epoch   71/100  Batch 1/3  Cost 0.5714
# Epoch   71/100  Batch 2/3  Cost 0.1183
# Epoch   71/100  Batch 3/3  Cost 0.0346
# Epoch   72/100  Batch 1/3  Cost 0.0320
# Epoch   72/100  Batch 2/3  Cost 0.4721
# Epoch   72/100  Batch 3/3  Cost 0.2379
# Epoch   73/100  Batch 1/3  Cost 0.5485
# Epoch   73/100  Batch 2/3  Cost 0.0864
# Epoch   73/100  Batch 3/3  Cost 0.0282
# Epoch   74/100  Batch 1/3  Cost 0.1797
# Epoch   74/100  Batch 2/3  Cost 0.6355
# Epoch   74/100  Batch 3/3  Cost 0.0015
# Epoch   75/100  Batch 1/3  Cost 0.4233
# Epoch   75/100  Batch 2/3  Cost 0.0016
# Epoch   75/100  Batch 3/3  Cost 0.3880
# Epoch   76/100  Batch 1/3  Cost 0.0754
# Epoch   76/100  Batch 2/3  Cost 0.1741
# Epoch   76/100  Batch 3/3  Cost 0.9048
# Epoch   77/100  Batch 1/3  Cost 0.2916
# Epoch   77/100  Batch 2/3  Cost 0.3189
# Epoch   77/100  Batch 3/3  Cost 0.4336
# Epoch   78/100  Batch 1/3  Cost 0.4637
# Epoch   78/100  Batch 2/3  Cost 0.1415
# Epoch   78/100  Batch 3/3  Cost 0.2293
# Epoch   79/100  Batch 1/3  Cost 0.5960
# Epoch   79/100  Batch 2/3  Cost 0.1048
# Epoch   79/100  Batch 3/3  Cost 0.1922
# Epoch   80/100  Batch 1/3  Cost 0.0534
# Epoch   80/100  Batch 2/3  Cost 0.5806
# Epoch   80/100  Batch 3/3  Cost 0.0678
# Epoch   81/100  Batch 1/3  Cost 0.1512
# Epoch   81/100  Batch 2/3  Cost 0.0700
# Epoch   81/100  Batch 3/3  Cost 0.8962
# Epoch   82/100  Batch 1/3  Cost 0.2498
# Epoch   82/100  Batch 2/3  Cost 0.4672
# Epoch   82/100  Batch 3/3  Cost 0.0066
# Epoch   83/100  Batch 1/3  Cost 0.1948
# Epoch   83/100  Batch 2/3  Cost 0.4422
# Epoch   83/100  Batch 3/3  Cost 0.0028
# Epoch   84/100  Batch 1/3  Cost 0.4235
# Epoch   84/100  Batch 2/3  Cost 0.0021
# Epoch   84/100  Batch 3/3  Cost 0.3839
# Epoch   85/100  Batch 1/3  Cost 0.5417
# Epoch   85/100  Batch 2/3  Cost 0.0722
# Epoch   85/100  Batch 3/3  Cost 0.0848
# Epoch   86/100  Batch 1/3  Cost 0.1383
# Epoch   86/100  Batch 2/3  Cost 0.4683
# Epoch   86/100  Batch 3/3  Cost 0.0234
# Epoch   87/100  Batch 1/3  Cost 0.1733
# Epoch   87/100  Batch 2/3  Cost 0.0884
# Epoch   87/100  Batch 3/3  Cost 0.8376
# Epoch   88/100  Batch 1/3  Cost 0.4857
# Epoch   88/100  Batch 2/3  Cost 0.2139
# Epoch   88/100  Batch 3/3  Cost 0.0184
# Epoch   89/100  Batch 1/3  Cost 0.2874
# Epoch   89/100  Batch 2/3  Cost 0.2567
# Epoch   89/100  Batch 3/3  Cost 0.3140
# Epoch   90/100  Batch 1/3  Cost 0.5577
# Epoch   90/100  Batch 2/3  Cost 0.0675
# Epoch   90/100  Batch 3/3  Cost 0.0912
# Epoch   91/100  Batch 1/3  Cost 0.3508
# Epoch   91/100  Batch 2/3  Cost 0.2635
# Epoch   91/100  Batch 3/3  Cost 0.2020
# Epoch   92/100  Batch 1/3  Cost 0.5814
# Epoch   92/100  Batch 2/3  Cost 0.3102
# Epoch   92/100  Batch 3/3  Cost 0.0575
# Epoch   93/100  Batch 1/3  Cost 0.4698
# Epoch   93/100  Batch 2/3  Cost 0.1423
# Epoch   93/100  Batch 3/3  Cost 0.0235
# Epoch   94/100  Batch 1/3  Cost 0.0952
# Epoch   94/100  Batch 2/3  Cost 0.4961
# Epoch   94/100  Batch 3/3  Cost 0.0082
# Epoch   95/100  Batch 1/3  Cost 0.1127
# Epoch   95/100  Batch 2/3  Cost 0.3955
# Epoch   95/100  Batch 3/3  Cost 0.4296
# Epoch   96/100  Batch 1/3  Cost 0.5316
# Epoch   96/100  Batch 2/3  Cost 0.0311
# Epoch   96/100  Batch 3/3  Cost 0.2018
# Epoch   97/100  Batch 1/3  Cost 0.0505
# Epoch   97/100  Batch 2/3  Cost 0.5552
# Epoch   97/100  Batch 3/3  Cost 0.0574
# Epoch   98/100  Batch 1/3  Cost 0.1154
# Epoch   98/100  Batch 2/3  Cost 0.3924
# Epoch   98/100  Batch 3/3  Cost 0.4326
# Epoch   99/100  Batch 1/3  Cost 0.4980
# Epoch   99/100  Batch 2/3  Cost 0.1291
# Epoch   99/100  Batch 3/3  Cost 0.2193
# Epoch  100/100  Batch 1/3  Cost 0.0728
# Epoch  100/100  Batch 2/3  Cost 0.6534
# Epoch  100/100  Batch 3/3  Cost 0.2319

# %%
# 임의의 값으로 예측값 확인
new_var = torch.FloatTensor([[73, 80, 75]])

pred_y = model(new_var) 
print("훈련 후 입력이 73, 80, 75일 때의 예측값 :", pred_y)
# Out:
# 훈련 후 입력이 73, 80, 75일 때의 예측값 : tensor([[151.0006]], grad_fn=<AddmmBackward>)
