# %%
import numpy as np

# %%
nb_list = ['0', '70000', '4300000000']

for i in nb_list:
    print('-'*30)
    print(i)
    print(type(i))
    i = np.int8(i)
    print(type(i))
# Out:
# ------------------------------
# 0
# <class 'str'>
# <class 'numpy.int8'>
# ------------------------------
# 70000
# <class 'str'>
# <class 'numpy.int8'>
# ------------------------------
# 4300000000
# <class 'str'>
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-23-8fae68ea73a1> in <module>
#       5     print(i)
#       6     print(type(i))
# ----> 7     i = np.int8(i)
#       8     print(type(i))
#
# OverflowError: Python int too large to convert to C long
